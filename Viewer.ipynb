# %%
from pathlib import Path
for ckpt in Path("logs").rglob("*.ckpt"):
    print(ckpt)
# Out:
# logs/2026-03-05/09-43-28/checkpoints/last.ckpt
# logs/2026-03-05/09-43-28/checkpoints/epoch=129-step=15600.ckpt

# %%
# Use the path that matches your file (e.g. best or last)
ckpt_path = next(Path("logs").rglob("*.ckpt"))
import torch
c = torch.load(ckpt_path, map_location="cpu")
print("Keys:", list(c.keys()))
print("Epoch:", c.get("epoch"), "Step:", c.get("global_step"))
# Out:
# Keys: ['epoch', 'global_step', 'pytorch-lightning_version', 'state_dict', 'loops', 'callbacks', 'optimizer_states', 'lr_schedulers', 'hparams_name', 'hyper_parameters']
# Epoch: 149 Step: 18000

# %% [markdown]
# Run  python -m emg2qwerty.train train=False checkpoint=logs/2026-03-05/09-43-28/checkpoints/<best>.ckpt
#
# To get the metrics of the best
